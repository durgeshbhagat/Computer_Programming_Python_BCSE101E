# %% [markdown]
# # Index
# - reserved keywords
# - in-built function

# %% [markdown]
# # reserved keyowrds in python

# %% [markdown]
# ![keywords list in python](https://drive.google.com/uc?export=view&id=1-yj6bfaCtaIdfp1E4a2Rc5t5U9zKsgAm)

# %%
import keyword
print(type(keyword.kwlist))
keywords_list = list(keyword.kwlist)
print(keywords_list)
print(len(keywords_list))
# Out:
# <class 'list'>
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# 35

# %%
import keyword
keywords_list = list(keyword.kwlist)
print(type(keywords_list[0]))
keywords_list.sort(key=lambda item: item.lower())
for i, keyword in enumerate(keywords_list):
  print(i+1, keyword)
# Out:
# <class 'str'>
# 1 and
# 2 as
# 3 assert
# 4 async
# 5 await
# 6 break
# 7 class
# 8 continue
# 9 def
# 10 del
# 11 elif
# 12 else
# 13 except
# 14 False
# 15 finally
# 16 for
# 17 from
# 18 global
# 19 if
# 20 import
# 21 in
# 22 is
# 23 lambda
# 24 None
# 25 nonlocal
# 26 not
# 27 or
# 28 pass
# 29 raise
# 30 return
# 31 True
# 32 try
# 33 while
# 34 with
# 35 yield

# %% [markdown]
# ## in-built fucntion

# %% [markdown]
# ![built-in function in python](https://drive.google.com/uc?export=view&id=1-mf-wseMaAAbNwUi3JpbSSLZV1ClBbpa)

# %% [markdown]
# *Reference* :https://docs.python.org/3/library/functions.html#built-in-funcs

# %%
##
