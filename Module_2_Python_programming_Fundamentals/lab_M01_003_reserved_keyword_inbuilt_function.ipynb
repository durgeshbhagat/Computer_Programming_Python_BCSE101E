# %% [markdown]
# # Importing a module and `if` condtional statement
#  - importing a module
#  - basic `if` statement

# %% [markdown]
# ## Importing a module

# %%
import numpy

# %%
import pandas as pd

# %%
import numpy
a = numpy.array([1,5, 7])
print(a)
# Out:
# [1 5 7]

# %%
import math

print(math.sqrt(9))
print(math.sqrt(12))
# Out:
# 3.0
# 3.4641016151377544

# %%
import sklearn # python machine learning library

# %%
import torch as torch # pytorch - deep learning library by facebook/Meta researc

# %%
# refer this to install pytorch library
# link: https://saturncloud.io/blog/how-to-install-pytorch-v100-on-google-colab-a-guide-for-data-scientists/

# !pip3 uninstall --yes torch torchaudio torchvision torchtext torchdata
# !pip3 install torch torchaudio torchvision torchtext torchdata
# Out:
# Found existing installation: torch 2.0.1+cu118
# Uninstalling torch-2.0.1+cu118:
#   Successfully uninstalled torch-2.0.1+cu118
# Found existing installation: torchaudio 2.0.2+cu118
# Uninstalling torchaudio-2.0.2+cu118:
#   Successfully uninstalled torchaudio-2.0.2+cu118
# Found existing installation: torchvision 0.15.2+cu118
# Uninstalling torchvision-0.15.2+cu118:
#   Successfully uninstalled torchvision-0.15.2+cu118
# Found existing installation: torchtext 0.15.2
# Uninstalling torchtext-0.15.2:
#   Successfully uninstalled torchtext-0.15.2
# Found existing installation: torchdata 0.6.1
# Uninstalling torchdata-0.6.1:
#   Successfully uninstalled torchdata-0.6.1
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 71.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 69.5 MB/s eta 0:00:00
# ...

# %%
import torch
print(torch.__version__)
# Out:
# 2.0.1+cu117

# %%
import tensorflow as tf # deep learning library by Google research
print(tf.__version__)
# Out:
# 2.12.0

# %% [markdown]
# ## Conditional statement -if

# %%
x = 8
if x > 5:
    print('x is greater than 5')
    print('another line inside if')
print('outside if statement')
# Out:
# x is greater than 5
# another line inside if
# outside if statement
