# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True )
# Out:
# Mounted at /content/drive

# %%
import os
base_path = '/content/drive/MyDrive/VIT_Vellore/FALL_2022_2023/Python/Python_Lab/Computer_Programming_Python_BCSE101E'

# %cd '/content/drive/MyDrive/VIT_Vellore/FALL_2022_2023/Python/Python_Lab/Computer_Programming_Python_BCSE101E'
# Out:
# /content/drive/MyDrive/VIT_Vellore/FALL_2022_2023/Python/Python_Lab/Computer_Programming_Python_BCSE101E

# %%
# %cd Module_6_Functions_and_Files
# Out:
# /content/drive/MyDrive/VIT_Vellore/FALL_2022_2023/Python/Python_Lab/Computer_Programming_Python_BCSE101E/Module_6_Functions_and_Files

# %%
# !ls
# Out:
#  file_read_write_demonstration.ipynb   Module_6_Files.gslides
# 'Function Practice problems.gslides'   Module_6_Function.pptx
#  images				       sample.txt
#  lab_11_2_function.ipynb	       VIT_BCSE101E_Functions.ipynb
#  lab_11_functions_practice.ipynb

# %%
# To read contents of file
file_object = open('sample.txt', 'r')
contents = file_object.read()
print(contents)
file_object.close()
# Out:
# S.No, RegistraionNo, Name
# 2, 22BCE0076, Tashi Sharma
# 40, 22BCE3064, Aryan Bhirud
# 62, 22BCE3646, Diya Afreen Mukesh

# %%
line_list = contents.split('\n')
print(line_list)
for item in line_list:
  print('---', item)
# Out:
# ['S.No, RegistraionNo, Name', '2, 22BCE0076, Tashi Sharma', '40, 22BCE3064, Aryan Bhirud', '62, 22BCE3646, Diya Afreen Mukesh']
# --- S.No, RegistraionNo, Name
# --- 2, 22BCE0076, Tashi Sharma
# --- 40, 22BCE3064, Aryan Bhirud
# --- 62, 22BCE3646, Diya Afreen Mukesh

# %%
file_object = open('sample.txt', 'r')
for i, line in enumerate(file_object):
    #if i%2 ==0:
    print(i,'->', line)
file_object.close()
# Out:
# 0 -> S.No, RegistraionNo, Name
#
# 1 -> 2, 22BCE0076, Tashi Sharma
#
# 2 -> 40, 22BCE3064, Aryan Bhirud
#
# 3 -> 62, 22BCE3646, Diya Afreen Mukesh

# %%
 with open('sample.txt', 'r') as fin:
    content = fin.read()
    print (content)
# Out:
# S.No, RegistraionNo, Name
# 2, 22BCE0076, Tashi Sharma
# 40, 22BCE3064, Aryan Bhirud
# 62, 22BCE3646, Diya Afreen Mukesh

# %%
file_object = open('sample.txt', 'r')
for line in file_object:
    print(line.strip())
file_object.close()
# Out:
# S.No, RegistraionNo, Name
# 2, 22BCE0076, Tashi Sharma
# 40, 22BCE3064, Aryan Bhirud
# 62, 22BCE3646, Diya Afreen Mukesh

# %% [markdown]
# ### readlines and readlines()

# %%
file_object = open('sample.txt', 'r')
line_list = file_object.readlines()
print(line_list)
for line in line_list:
    print(line)
file_object.close()
# Out:
# ['S.No, RegistraionNo, Name\n', '2, 22BCE0076, Tashi Sharma\n', '40, 22BCE3064, Aryan Bhirud\n', '62, 22BCE3646, Diya Afreen Mukesh']
# S.No, RegistraionNo, Name
#
# 2, 22BCE0076, Tashi Sharma
#
# 40, 22BCE3064, Aryan Bhirud
#
# 62, 22BCE3646, Diya Afreen Mukesh

# %%
print(line_list)

# %% [markdown]
# ## Writing to files

# %%
# !ls
# Out:
#  file_read_write_demonstration.ipynb   Module_6_Files.gslides
# 'Function Practice problems.gslides'   Module_6_Function.pptx
#  images				       sample.txt
#  lab_11_2_function.ipynb	       VIT_BCSE101E_Functions.ipynb
#  lab_11_functions_practice.ipynb

# %%
fname = 'sample_out.csv'
fo = open(fname, 'w')
fo.write("I am, learning, Python")
fo.write(" Python is, interesting, language")
fo.close()

# %%
# !ls -l
# Out:
# total 1472
# -rw------- 1 root root   10406 Jan 10 12:33  file_read_write_demonstration.ipynb
# -rw------- 1 root root     178 Oct 19 12:51 'Function Practice problems.gslides'
# drwx------ 2 root root    4096 Dec  6 20:41  images
# -rw------- 1 root root   58131 Dec 20 11:58  lab_11_2_function.ipynb
# -rw------- 1 root root    9578 Dec  6 22:48  lab_11_functions_practice.ipynb
# -rw------- 1 root root     178 Jan 10 11:45  Module_6_Files.gslides
# -rw------- 1 root root 1255562 Dec  6 08:33  Module_6_Function.pptx
# -rw------- 1 root root      55 Jan 10 12:32  sample_out.csv
# -rw------- 1 root root     117 Jan 10 05:31  sample.txt
# -rw------- 1 root root  166030 Nov 29 15:43  VIT_BCSE101E_Functions.ipynb

# %%
# !cat  sample_out.csv
# Out:
# I am, learning, Python Python is, interesting, language

# %%
fname = 'sample_out.csv'
fo = open(fname, 'w')
fo.write("Today is Tuesday\n")
fo.write("We are learnign File concepts")
fo.close()

# %%
# !cat  sample_out.csv
# Out:
# Today is Tuesday
# We are learnign File concepts

# %% [markdown]
# ### Appending to files

# %%
fname = 'sample_out.csv'
fo = open(fname, 'a')
fo.write("\nIN OOPS, we are going to, learn C and C plus")
fo.write("\nC and C plus, will be, used in DSA")
fo.close()

# %%
# !cat  sample_out.csv
# Out:
# Today is Tuesday
# We are learnign File concepts
# IN OOPS, we are going to, learn C and C plus
# C and C plus, will be, used in DSA

# %%
# !head  sample_out.csv
# Out:
# I am, learning, Python Python is, interesting, language
# (END)

# %%
fname = 'sample_out.csv'
fin = open(fname, 'r')
st = fin.read()
st_list = st.split('\n')
print(st_list)
# Out:
# ['Today is Tuesday', 'We are learnign File concepts', 'IN OOPS, we are going to, learn C and C plus', 'C and C plus, will be, used in DSA']

# %%
st2_list = st.split(',')
print(st2_list)
# Out:
# ['Today is Tuesday\nWe are learnign File concepts\nIN OOPS', ' we are going to', ' learn C and C plus\nC and C plus', ' will be', ' used in DSA']

# %%
fin.close()

# %%
fin = open(fname, 'r')
count =0
while count!=4:
  print(fin.readline())
  count +=1
# Out:
# Today is Tuesday
#
# We are learnign File concepts
#
# IN OOPS, we are going to, learn C and C plus
#
# C and C plus, will be, used in DSA
