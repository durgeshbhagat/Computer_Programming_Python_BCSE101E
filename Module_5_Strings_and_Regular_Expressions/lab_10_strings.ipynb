# %% [markdown]
# # Strings
#
# - creating a string
# - string methods

# %%
# Creating a String with single Quotes
String1 = 'Welcome to the Geeks World'
print("String with the use of Single Quotes: ")
print(String1)
# Out:
# String with the use of Single Quotes:
# Welcome to the Geeks World

# %%
# Creating a String with double Quotes
String1 = "I'm a Geek"
print("\nString with the use of Double Quotes: ")
print(String1)
# Out:
# String with the use of Double Quotes:
# I'm a Geek

# %%
# Creating a String  with triple Quotes
String1 = '''I'm a Geek and I live in a world of "Geeks"'''
print("\nString with the use of Triple Quotes: ")
print(String1)
# Out:
# String with the use of Triple Quotes:
# I'm a Geek and I live in a world of "Geeks"

# %%
# Creating a String  with triple double quote  Quotes
String1 = """ I'm a Geek and I live in a world of "Geeks" """
print("\nString with the use of Triple Quotes: ")
print(String1)
# Out:
# String with the use of Triple Quotes:
#  I'm a Geek and I live in a world of "Geeks"

# %% [markdown]
# ## acessing a string - indexing similar to list and tuple

# %%
st = 'I am learning Python in GDN 153'
print(st[0])
# Out:
# I

# %%
# acess Python
print(st[14:20])
# Out:
# Python

# %%
# access GDN 153
print(st[-7:])
# Out:
# GDN 153

# %%
# negative index

# %% [markdown]
# ## replacing value
# - replace GDN 153 to SJT 214 in above string

# %%
st[-1]= "4"
print(st)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-dcc179d6a630> in <module>
# ----> 1 st[-1]= "4"
#       2 print(st)
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ## string slicing, splitiing and stripping
