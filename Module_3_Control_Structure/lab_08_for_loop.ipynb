# %%
lang_list = ['Python', 'C',  'C++', 'Java', ' Maths']
for item in lang_list:
  print(item)
# Out:
# Python
# C
# C++
# Java
#  Maths

# %%
name = "Durgesh Kumar"
word_list = name.split(' ')
print(word_list)
print(len(word_list))
# Out:
# ['Durgesh', 'Kumar']
# 2

# %%
name = "Durgesh Kumar"
space_count =0
for ch in name:
  if ch == ' ':
    space_count += 1
print(f'space_count={space_count}')
print(f'word_count={space_count+1}')
# Out:
# space_count=1
# word_count=2

# %%
for i in range(6):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
