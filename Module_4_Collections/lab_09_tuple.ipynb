# %% [markdown]
# # Tuples
# - a collection of Python objects like list
# - can contain heterogenous objects (data types)
# - is immutable

# %% [markdown]
# ## Intialize a tuple

# %%
# tuple as hetegeneous element
my_tuple = (1, 'ram', 64.89, None, False)
print(my_tuple)
# Out:
# (1, 'ram', 64.89, None, False)

# %%
# tuple as homogenous element
my_tuple = (1, 19, 48, 64, 97)
print(my_tuple)
# Out:
# (1, 19, 48, 64, 97)

# %%
# tuple as a collection of tuple
my_tuple = ( (47.89, 32.64) ,(48.57, 64.09) , (97.87, 14.80) )
print(my_tuple)
# Out:
# ((47.89, 32.64), (48.57, 64.09), (97.87, 14.8))

# %%
my_tuple = ( [47.89, 32.64] , [48.57, 64.09] , [97.87, 14.80], [20.45, 93.67] )
print(my_tuple)
print(id(my_tuple))
print(id(my_tuple[1]))
my_tuple[1].append(34)
print(id(my_tuple[1]))
print(my_tuple)
# Out:
# ([47.89, 32.64], [48.57, 64.09], [97.87, 14.8], [20.45, 93.67])
# 139857658686256
# 139857524071152
# 139857524071152
# ([47.89, 32.64], [48.57, 64.09, 34], [97.87, 14.8], [20.45, 93.67])

# %%
# tuple as a collection of list

# %% [markdown]
# ## indexing a tuple
# - similar to list

# %%
print(my_tuple)
print(my_tuple[0])
print(my_tuple[-1])
print(my_tuple[1][1])
# Out:
# ([47.89, 32.64], [48.57, 64.09], [97.87, 14.8], [20.45, 93.67])
# [47.89, 32.64]
# [20.45, 93.67]
# 64.09

# %%
# slicing to pick up second and third entry of tuple
print(my_tuple[1:3])
print(my_tuple[1:4:2])
# Out:
# ('ram', 64.89)
# ('ram', None)

# %% [markdown]
# ## Imutable property

# %%
my_tuple = (1, 19, 48, 64, 97)
print(my_tuple)
# Out:
# (1, 19, 48, 64, 97)

# %%
my_tuple[1] = 24
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-54df4f019651> in <module>
# ----> 1 my_tuple[1] = 24
#
# TypeError: 'tuple' object does not support item assignment

# %%
del my_tuple[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-3915e824501e> in <module>
# ----> 1 del my_tuple[1]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
my_tuple.append(27)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-eedaa99c4408> in <module>
# ----> 1 my_tuple.append(27)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
my_tuple.insert(1, 27)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-f468203e8d5b> in <module>
# ----> 1 my_tuple.insert(1, 27)
#
# AttributeError: 'tuple' object has no attribute 'insert'

# %%
print(my_tuple)
my_tuple = (21, 19)
print(my_tuple)
# Out:
# (1, 19, 48, 64, 97)
# (21, 19)

# %% [markdown]
# ##  Operation on tuple
# - insertion/deletion - not allowed
# - updating a part of value - not allowed
# - Searching/Conting an element - .index, count

# %%
help(my_tuple)
# Out:
# Help on tuple object:
#
# class tuple(object)
#  |  tuple(iterable=(), /)
#  |
#  |  Built-in immutable sequence.
#  |
#  |  If no argument is given, the constructor returns an empty tuple.
#  |  If iterable is specified the tuple is initialized from iterable's items.
#  |
#  |  If the argument is a tuple, the return value is the same object.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
#  |  __getnewargs__(self, /)
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __mul__(self, value, /)
#  |      Return self*value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __rmul__(self, value, /)
#  |      Return value*self.
#  |
#  |  count(self, value, /)
#  |      Return number of occurrences of value.
#  |
#  |  index(self, value, start=0, stop=9223372036854775807, /)
#  |      Return first index of value.
#  |
#  |      Raises ValueError if the value is not present.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.

# %%
t1= (1, 'ram')
t2 = (2, 'shyam')
t = t1+t2
print(t1)
print(t2)
print(t)
# Out:
# (1, 'ram')
# (2, 'shyam')
# (1, 'ram', 2, 'shyam')
