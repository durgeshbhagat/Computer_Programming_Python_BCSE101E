# %% [markdown]
# # Dictionary
# - a key-value pair.
# - used to store data values like a map (hashing).
#
# **Dictionary in Python** is a collection of keys values, used to store data values like a map, which, unlike other data types which hold only a single value as an element.

# %% [markdown]
# ### Properties of Keys and Values of dictionary
# **Keys**:
# - keys in a dictionary can not be repeated.
# - keys must be immutable.
#
# **Values**
# - Values in a dictionary can be of any data type.
# - Values can be duplicated

# %% [markdown]
# ## Initialize/Create a dictionary with following entry
# {1: 'Python', 2: 'Java', 3: 'Ruby', 4: 'Scala'}

# %%
d= { 8 : 'cppp',
    3: 'Python', 2: 'Java', 1: 'Ruby',
    11: 'Cplus',
    4: 'Scala'}

# %%
keys_list = list(d.keys())
print(keys_list)
keys_list.sort()
print(keys_list)
# Out:
# [3, 2, 1, 4]
# [1, 2, 3, 4]

# %%
values_list = list(d.values())
print(values_list)
values_list.sort()
print(values_list)
# Out:
# ['Python', 'Java', 'Ruby', 'Scala']
# ['Java', 'Python', 'Ruby', 'Scala']

# %%
values_list.sort(key=lambda item: len(item))
print(values_list)
# Out:
# ['Java', 'Ruby', 'Scala', 'Python']

# %%
def my_add(x, y):
  z = x+y
  return z

# %%
t = my_add(2,3)
print(t)
# Out:
# 5

# %%
items_list = list(d.items())
print(items_list)
items_list.sort()
print(items_list)
# Out:
# [(8, 'cppp'), (3, 'Python'), (2, 'Java'), (1, 'Ruby'), (11, 'Cplus'), (4, 'Scala')]
# [(1, 'Ruby'), (2, 'Java'), (3, 'Python'), (4, 'Scala'), (8, 'cppp'), (11, 'Cplus')]

# %%
items_list.sort(key = lambda item : (len(item[1]), item[0]), reverse=True)
print(items_list)
# Out:
# [(3, 'Python'), (11, 'Cplus'), (4, 'Scala'), (8, 'cppp'), (2, 'Java'), (1, 'Ruby')]
